# %%
import auth 
dhan = auth.login()
# Out:
# Doing fresh TOTP login...
# Login successful. Token saved to config.
# Ready. Token: eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJ...

# %%
result = dhan.get_fund_limits()
result
# Out:
# {'status': 'success',
#  'remarks': '',
#  'data': {'dhanClientId': '1100605239',
#   'availabelBalance': 67861.26,
#   'sodLimit': 36882.55,
#   'collateralAmount': 0.0,
#   'receiveableAmount': 0.0,
#   'utilizedAmount': 617.0,
#   'blockedPayoutAmount': 0.0,
#   'withdrawableBalance': 36573.05}}
